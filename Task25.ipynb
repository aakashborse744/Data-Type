# %% [markdown]
# ## Find max , second max and min , second min on that list.
# ## ->By using for loop.

# %%
## find First max number in that list.
l1 = [30,95,66,78,95,85,30,66,95,85,30,66,95,85,30,66]

max =l1 [0]
for num in l1:
    if num > max1:
        max1 = num
print("max number =", max1)
# Out:
# max number = 95

# %%
## Find second maximun number in that list.
# max = max2 = l[0]  # initialize both before the loop
for num in l1:
    if num > max1:
        max2 = max1
        max1 = num
    elif num > max2 and num != max1:
        max2 = num
print("second max number=",max2)
# Out:
# second max number= 85

# %%
## Find the first minimum number in that list.
min1 = l1[0]
for num in l1:
    if num < min1:
        min1 = num
print("first min number=", min1)
# Out:
# first min number= 30

# %%
## Find the second minimum number in that list
min1 = float('inf')     ##float('inf') represents infinity — a value larger than any real number that could ever appear in your list
min2 = float('inf')

for num in l1:
    if num < min1:
        min2 = min1
        min1 = num
    elif num < min2 and num != min1:
        min2 = num
print("second min number =", min2)
# Out:
# second min number = 66
